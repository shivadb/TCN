# %%
import tensorrt as trt

# %%
dir(trt)
# Out:
# ['ActivationType',
#  'Builder',
#  'BuilderFlag',
#  'CURDIR',
#  'CaffeParser',
#  'CalibrationAlgoType',
#  'DataType',
#  'DeviceType',
#  'DimensionType',
#  'Dims',
#  'Dims2',
#  'Dims3',
#  'Dims4',
#  'DimsCHW',
#  'DimsHW',
#  'DimsNCHW',
#  'ElementWiseOperation',
#  'ErrorCode',
#  'ErrorCodeTRT',
#  'FallbackString',
#  'FieldCollection',
#  'FieldMap',
#  'FieldType',
#  'FillOperation',
#  'IActivationLayer',
#  'IAlgorithm',
#  'IAlgorithmContext',
#  'IAlgorithmIOInfo',
#  'IAlgorithmSelector',
#  'IAlgorithmVariant',
#  'IBlobNameToTensor',
#  'IBuilderConfig',
#  'ICaffePluginFactory',
#  'ICaffePluginFactoryExt',
#  'ICaffePluginFactoryV2',
#  'IConcatenationLayer',
#  'IConstantLayer',
#  'IConvolutionLayer',
#  'ICudaEngine',
#  'IDeconvolutionLayer',
#  'IElementWiseLayer',
#  'IErrorRecorder',
#  'IExecutionContext',
#  'IFillLayer',
#  'IFullyConnectedLayer',
#  'IGatherLayer',
#  'IGpuAllocator',
#  'IHostMemory',
#  'IIdentityLayer',
#  'IInt8Calibrator',
# ...

# %%
dir(trt.ITensor)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'allowed_formats',
#  'broadcast_across_batch',
#  'dtype',
#  'dynamic_range',
#  'get_dynamic_range',
#  'is_execution_tensor',
#  'is_network_input',
#  'is_network_output',
#  'is_shape_tensor',
#  'location',
#  'name',
#  'reset_dynamic_range',
#  'set_dynamic_range',
#  'shape']

# %%
ditrt.Weights
# Out:
# tensorrt.tensorrt.Weights
